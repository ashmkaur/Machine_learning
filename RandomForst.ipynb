# %%
#Polynomial Regression

#Classification

#SUPERVISED LEARNING 

import numpy as py
import matplotlib.pyplot as plt
import pandas as pd

dataset= pd.read_csv('Poly_dataset.csv')
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,1].values


# Polynomial regression
from sklearn.ensemble import RandomForestRegressor
lin_reg= RandomForestRegressor(n_estimators=10,random_state=0)
lin_reg.fit(X,Y)

plt.scatter(X,Y,color='red')
plt.plot(X,lin_reg.predict(X),color='black')
plt.title("Level VS Salary")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# Regressor
x_grid= py.arange(min(X),max(X),0.1)
x_grid= x_grid.reshape(len(x_grid),1)
plt.scatter(X,Y,color='red')
plt.plot(x_grid,lin_reg.predict(x_grid),color='black')
plt.title("Level VS Salary")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()


# which quite obvious regarding interval in which 6.5 lies 

lin_reg.predict(py.reshape(6.5,(1,1)))
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_30376\1123111252.py:29: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid= py.arange(min(X),max(X),0.1)
# array([167000.])
